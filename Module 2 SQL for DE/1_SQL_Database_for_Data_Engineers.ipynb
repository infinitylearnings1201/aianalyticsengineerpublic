# %% [markdown]
# # Day 1: What is a Database?

# %% [markdown]
# When students hear the word database for the first time, many of them imagine something mysterious, locked away in giant servers. But in reality, a database is just a smarter and more structured version of something you already know very well: an Excel sheet.

# %% [markdown]
# ![](/Volumes/thedataengineering_00/data/sampledata/sampleimages/1_excel.png)

# %% [markdown]
# Think of Excel. You have rows and columns. Each column has a name, such as Name, Age, or Salary. Each row contains the actual data, such as Alice, 30, 60,000. A database table works the same way. The difference is that instead of opening one file at a time on your laptop, databases are designed to store millions (or billions) of rows, keep them organized, and allow many people or applications to use them simultaneously without breaking anything.

# %% [markdown]
# # From Excel to Databases

# %% [markdown]
# Imagine your college placement cell keeps student information in an Excel file. It works fine for a few hundred students. But what happens when you join a company that manages data for millions of customers, or thousands of employees across different offices? Suddenly, Excel starts to break. Files get too large, multiple people can't edit at the same time, and searching becomes painfully slow.

# %% [markdown]
# ![](/Volumes/thedataengineering_00/data/sampledata/sampleimages/1_db.png)

# %% [markdown]
# This is where databases come in. A database is a system that:
# - Stores data reliably (no matter how big).
# - Organizes it into tables (just like structured sheets).
# - Provides tools to query and analyze the data efficiently.
# - Ensures that multiple people can work with the data without conflict.

# %% [markdown]
# # Introducing SQL

# %% [markdown]
# So how do we talk to a database? That's where SQL (Structured Query Language) comes in.
# SQL is like the language of databases. If the database is the library, then SQL is the librarian you talk to:
#
# "Can you give me a list of all employees in the IT department?"
#
# "Please update Bob's salary to 80,000."
#
# "Remove the record of the employee who left last month."
#
# SQL makes these requests possible. You don't need to know how the database engine actually stores the data internally - SQL abstracts that complexity and gives you a clear, English-like way to communicate.

# %% [markdown]
# # Why SQL for Data Engineers?

# %% [markdown]
# As a future data engineer, you will be the one building pipelines that move data from raw sources into structured, usable formats. You will need to clean messy logs, join information from different systems, and prepare it for analytics or machine learning.
#
# Almost all of this relies on SQL at some stage. Even if you later learn Spark, Python, or big data frameworks, you'll notice they all embed SQL concepts - grouping, joining, filtering, aggregating. In fact, many large companies still depend on SQL as their backbone for reporting and decision-making.
#
# SQL is to data what mathematics is to engineering - a foundation you cannot skip.
#
# Let's take our teaching schema with two simple tables:

# %% [markdown]
# Department Table

# %%
# %sql

select * from thedataengineering_00.company.department

# %% [markdown]
# Employees Table

# %%
# %sql

select * from thedataengineering_00.company.employees

# %%
# %sql

SELECT first_name, last_name, salary
FROM thedataengineering_00.company.employees
WHERE dept_id = 3;

# %% [markdown]
# Today, we just built the bridge between something you know (Excel) and something you will master (databases with SQL). From here on, we'll dive deeper - into data types, creating tables, and actually shaping the data we store.
